# %% [markdown]
# <a href="https://colab.research.google.com/github/Alan1s/AlzheimerClasification/blob/main/analisis2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Parte 2 Proyecto Final**
# *   Alanis Nicole Forero Salas
# *   Kevin Jaimes Carrillo
# *   Juan Buitrago

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
train_data = pd.read_csv('entrenamiento.csv')

# %%
validation_data = pd.read_csv('prueba.csv')

# %% [markdown]
# Cargar datos

# %%
train_data.head()
# Out:
#    YearStart  YearEnd Datasource DataValueTypeID  Data_Value_Alt  \
# 0       2019     2019      BRFSS           PRCTG            32.3
# 1       2019     2019      BRFSS           PRCTG            48.8
# 2       2017     2017      BRFSS           PRCTG            32.3
# 3       2019     2019      BRFSS           PRCTG            26.0
# 4       2018     2018      BRFSS           PRCTG            60.1
#
#   Data_Value_Footnote_Symbol  Low_Confidence_Limit  High_Confidence_Limit  \
# 0                          ~                  26.5                   38.4
# 1                       ****                  26.5                   38.4
# 2                       ****                  26.5                   38.4
# 3                       ****                  26.5                   38.4
# 4                       ****                  50.4                   69.0
#
#   ClassID TopicID QuestionID  LocationID StratificationCategoryID1  \
# ...

# %%
validation_data.head()
# Out:
#    YearStart  YearEnd Datasource DataValueTypeID  Data_Value_Alt  \
# 0       2015     2015      BRFSS           PRCTG            41.7
# 1       2020     2020      BRFSS            MEAN             3.4
# 2       2020     2020      BRFSS           PRCTG            10.8
# 3       2015     2015      BRFSS           PRCTG            32.3
# 4       2021     2021      BRFSS           PRCTG            88.1
#
#   Data_Value_Footnote_Symbol  Low_Confidence_Limit  High_Confidence_Limit  \
# 0                       ****                  26.5                   38.4
# 1                       ****                   2.7                    4.1
# 2                       ****                   8.5                   13.6
# 3                       ****                  26.5                   38.4
# 4                       ****                  85.8                   90.1
#
#   ClassID TopicID QuestionID  LocationID StratificationCategoryID1  \
# ...

# %%
entrenamiento_adicional, validacion = train_test_split(train_data, test_size=0.2, random_state=42)

# %% [markdown]
# Train2

# %%
entrenamiento_adicional_encoded = pd.get_dummies(entrenamiento_adicional, drop_first=True)
validacion_encoded = pd.get_dummies(validacion, drop_first=True)

# %%
entrenamiento_adicional_encoded.head()
# Out:
#         YearStart  YearEnd  Data_Value_Alt  Low_Confidence_Limit  \
# 163761       2016     2021            44.2                  35.2
# 97931        2017     2017            62.2                  48.3
# 85900        2021     2021            32.3                  26.5
# 168227       2021     2021            32.3                  26.5
# 143976       2016     2016            41.4                  29.5
#
#         High_Confidence_Limit  LocationID  Z_Score_Data_Value  \
# 163761                   53.5          36            0.408163
# 97931                    74.4           2            1.271750
# 85900                    38.4          46           -0.162763
# 168227                   38.4          39           -0.162763
# 143976                   54.4          38            0.273828
#
#         LocationDesc_encoded  DataValueTypeID_PRCTG  \
# 163761                    34                   True
# 97931                      1                   True
# ...
